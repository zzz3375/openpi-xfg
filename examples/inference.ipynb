# %%
import dataclasses

import jax

from openpi.models import model as _model
from openpi.policies import droid_policy
from openpi.policies import policy_config as _policy_config
from openpi.shared import download
from openpi.training import config as _config
from openpi.training import data_loader as _data_loader

from pathlib import Path
# Out:
# /home/xfg/openpi/.venv/lib/python3.11/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]

# %% [markdown]
# # Policy inference
#
# The following example shows how to create a policy from a checkpoint and run inference on a dummy example.

# %%
config = _config.get_config("pi05_xfg")
# checkpoint_dir = download.maybe_download("gs://openpi-assets/checkpoints/pi0_fast_droid")
checkpoint_dir = Path("/home/xfg/openpi/checkpoints/pi05_xfg/pi05_xfg/199999")
# Create a trained policy.
policy = _policy_config.create_trained_policy(config, checkpoint_dir)

# Run inference on a dummy example. This example corresponds to observations produced by the DROID runtime.
example = droid_policy.make_droid_example()
result = policy.infer(example)

# Delete the policy to free up memory.
del policy

print("Actions shape:", result["actions"].shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 9
#       7 # Run inference on a dummy example. This example corresponds to observations produced by the DROID runtime.
#       8 example = droid_policy.make_droid_example()
# ----> 9 result = policy.infer(example)
#      11 # Delete the policy to free up memory.
#      12 del policy
#
# File ~/openpi/src/openpi/policies/policy.py:71, in Policy.infer(self, obs, noise)
#      67 @override
#      68 def infer(self, obs: dict, *, noise: np.ndarray | None = None) -> dict:  # type: ignore[misc]
#      69     # Make a copy since transformations may modify the inputs in place.
#      70     inputs = jax.tree.map(lambda x: x, obs)
# ---> 71     inputs = self._input_transform(inputs)
#      72     if not self._is_pytorch_model:
#      73         # Make a batch and convert to jax.Array.
#      74         inputs = jax.tree.map(lambda x: jnp.asarray(x)[np.newaxis, ...], inputs)
#
# File ~/openpi/src/openpi/transforms.py:70, in CompositeTransform.__call__(self, data)
#      68 def __call__(self, data: DataDict) -> DataDict:
#      69     for transform in self.transforms:
# ---> 70         data = transform(data)
#      71     return data
#
# File ~/openpi/src/openpi/policies/piper_policy.py:24, in PiperInputs.__call__(self, data)
#      23 def __call__(self, data: dict) -> dict:
# ---> 24     base_image = _parse_image(data["observation/image"])
#      25     wrist_image = _parse_image(data["observation/wrist_image"])
#      27     match self.model_type:
#
# KeyError: 'observation/image'

# %%
example['observation/exterior_image_1_left'].shape
# Out:
# (224, 224, 3)

# %% [markdown]
# # Working with a live model
#
#
# The following example shows how to create a live model from a checkpoint and compute training loss. First, we are going to demonstrate how to do it with fake data.

# %%
# config = _config.get_config("pi05_xfg")

# checkpoint_dir = checkpoint_dir = Path("/home/xfg/openpi/checkpoints/pi05_xfg/pi05_xfg/199999")
# key = jax.random.key(0)



# # Create a model from the checkpoint.
# # model = config.model.load(_model.restore_params(checkpoint_dir / "params"))

# # We can create fake observations and actions to test the model.
# obs, act = config.model.fake_obs(), config.model.fake_act()

# # Sample actions from the model.
# loss = model.compute_loss(key, obs, act)
# print("Loss shape:", loss.shape)
# print("Loss",loss)
# Out:
# Loss shape: (1, 10)
# Loss [[9.808524  9.121678  7.8784566 8.5600605 8.297195  7.95955   8.442614
#   7.7067037 9.34474   8.948059 ]]

# %% [markdown]
# Now, we are going to create a data loader and use a real batch of training data to compute the loss.

# %%
# # Reduce the batch size to reduce memory usage.
# config = dataclasses.replace(config, batch_size=1)

# # Load a single batch of data. This is the same data that will be used during training.
# # NOTE: In order to make this example self-contained, we are skipping the normalization step
# # since it requires the normalization statistics to be generated using `compute_norm_stats`.
# loader = _data_loader.create_data_loader(config, num_batches=1, skip_norm_stats=False, shuffle=True)
# obs, act = next(iter(loader))

# # Sample actions from the model.
# loss = model.compute_loss(key, obs, act)

# # Delete the model to free up memory.
# print("Loss shape:", loss.shape)
# print("Loss",loss)
# Out:
# Resolving data files:   0%|          | 0/76 [00:00<?, ?it/s]
# Loss shape: (1, 10)
# Loss [[0.03237168 0.0333537  0.0313825  0.02297497 0.0260726  0.04043334
#   0.04260989 0.04491493 0.03553791 0.03491812]]
